# %%
import psycopg2
import pgadmin_password
import pandas as pd

# %%
conn = psycopg2.connect(database="Wine_Quality_DB",
                        host="localhost",
                        user="postgres",
                        password=pgadmin_password.pgadmin_password,
                        port="5432")

# %%
cursor = conn.cursor()

# %%
cursor.execute("SELECT * FROM wine")

# %%
fetched = cursor.fetchall()

# %%
colnames = [desc[0] for desc in cursor.description]
colnames

# %%
df = pd.DataFrame(fetched, columns=colnames)
df.head()
# Out:
#    wine_id  wine_type_id fixed_acidity volatile_acidity citric_acid  \
# 0        1             0           7.4              0.7         0.0
# 1        2             0           7.8             0.88         0.0
# 2        3             0           7.8             0.76        0.04
# 3        4             0          11.2             0.28        0.56
# 4        5             0           7.4              0.7         0.0
#
#   residual_sugar chlorides  free_sulfur_dioxide  total_sulfure_dioxide  \
# 0            1.9     0.076                   11                     34
# 1            2.6     0.098                   25                     67
# 2            2.3     0.092                   15                     54
# 3            1.9     0.075                   17                     60
# 4            1.9     0.076                   11                     34
#
#   density    ph sulphates alcohol  quality
# 0  0.9978  3.51      0.56     9.4        5
# 1  0.9968   3.2      0.68     9.8        5
# 2   0.997  3.26      0.65     9.8        5
# 3   0.998  3.16      0.58     9.8        6
# 4  0.9978  3.51      0.56     9.4        5

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#       wine_id  wine_type_id fixed_acidity volatile_acidity citric_acid  \
# 0           1             0           7.4              0.7         0.0
# 1           2             0           7.8             0.88         0.0
# 2           3             0           7.8             0.76        0.04
# 3           4             0          11.2             0.28        0.56
# 4           5             0           7.4              0.7         0.0
# ...       ...           ...           ...              ...         ...
# 6492     6493             1           6.2             0.21        0.29
# 6493     6494             1           6.6             0.32        0.36
# 6494     6495             1           6.5             0.24        0.19
# 6495     6496             1           5.5             0.29         0.3
# 6496     6497             1           6.0             0.21        0.38
#
#      residual_sugar chlorides  free_sulfur_dioxide  total_sulfure_dioxide  \
# 0               1.9     0.076                   11                     34
# 1               2.6     0.098                   25                     67
# 2               2.3     0.092                   15                     54
# 3               1.9     0.075                   17                     60
# 4               1.9     0.076                   11                     34
# ...             ...       ...                  ...                    ...
# 6492            1.6     0.039                   24                     92
# 6493            8.0     0.047                   57                    168
# 6494            1.2     0.041                   30                    111
# 6495            1.1     0.022                   20                    110
# 6496            0.8      0.02                   22                     98
#
#       density    ph sulphates alcohol  quality
# 0      0.9978  3.51      0.56     9.4        5
# 1      0.9968   3.2      0.68     9.8        5
# 2       0.997  3.26      0.65     9.8        5
# 3       0.998  3.16      0.58     9.8        6
# 4      0.9978  3.51      0.56     9.4        5
# ...       ...   ...       ...     ...      ...
# 6492  0.99114  3.27       0.5    11.2        6
# 6493   0.9949  3.15      0.46     9.6        5
# 6494  0.99254  2.99      0.46     9.4        6
# 6495  0.98869  3.34      0.38    12.8        7
# 6496  0.98941  3.26      0.32    11.8        6
#
# [6497 rows x 14 columns]
