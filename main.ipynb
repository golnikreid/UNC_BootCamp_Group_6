# %%
# Import packages
import psycopg2
import pgadmin_password
import pandas as pd

# %%
# Create connection object for AWS
conn = psycopg2.connect(database="Wine_Quality",
                        host="wine-quality-db.c9tisna2dx0v.us-east-2.rds.amazonaws.com",
                        user="postgres",
                        password=pgadmin_password.pgadmin_password,
                        port="5432")

# %%
# Create cursor
cursor = conn.cursor()

# %%
# Execute command to pgAdmin
cursor.execute("SELECT * FROM wine")

# %%
fetched = cursor.fetchall()

# %%
# Pull out column names
colnames = [desc[0] for desc in cursor.description]
colnames
# Out:
# ['wine_id',
#  'wine_type_id',
#  'fixed_acidity',
#  'volatile_acidity',
#  'citric_acid',
#  'residual_sugar',
#  'chlorides',
#  'free_sulfur_dioxide',
#  'total_sulfure_dioxide',
#  'density',
#  'ph',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
# Create dataframe
df = pd.DataFrame(fetched, columns=colnames)
df.head()
# Out:
#    wine_id  wine_type_id fixed_acidity volatile_acidity citric_acid  \
# 0        1             0           7.4              0.7         0.0
# 1        2             0           7.8             0.88         0.0
# 2        3             0           7.8             0.76        0.04
# 3        4             0          11.2             0.28        0.56
# 4        5             0           7.4              0.7         0.0
#
#   residual_sugar chlorides  free_sulfur_dioxide  total_sulfure_dioxide  \
# 0            1.9     0.076                   11                     34
# 1            2.6     0.098                   25                     67
# 2            2.3     0.092                   15                     54
# 3            1.9     0.075                   17                     60
# 4            1.9     0.076                   11                     34
#
#   density    ph sulphates alcohol  quality
# 0  0.9978  3.51      0.56     9.4        5
# ...

# %%
# Change index to wine_id
df = df.set_index('wine_id')
df.head()
# Out:
#          wine_type_id fixed_acidity volatile_acidity citric_acid  \
# wine_id
# 1                   0           7.4              0.7         0.0
# 2                   0           7.8             0.88         0.0
# 3                   0           7.8             0.76        0.04
# 4                   0          11.2             0.28        0.56
# 5                   0           7.4              0.7         0.0
#
#         residual_sugar chlorides  free_sulfur_dioxide  total_sulfure_dioxide  \
# wine_id
# 1                  1.9     0.076                   11                     34
# 2                  2.6     0.098                   25                     67
# 3                  2.3     0.092                   15                     54
# 4                  1.9     0.075                   17                     60
# 5                  1.9     0.076                   11                     34
#
#         density    ph sulphates alcohol  quality
# wine_id
# ...

# %%
# Check for nulls
df.isnull().values.any()
# Out:
# False
